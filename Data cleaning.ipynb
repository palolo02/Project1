# %%
import pandas as pd
import numpy as np
from bokeh.io import output_notebook
from bokeh.plotting import figure, show
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
df = pd.read_csv(r'C:\Users\1000204905\Desktop\GitHub\Project1\gun_violence.csv')

# %%
df.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'address', 'n_killed',
#        'n_injured', 'incident_url', 'source_url',
#        'incident_url_fields_missing', 'congressional_district', 'gun_stolen',
#        'gun_type', 'incident_characteristics', 'latitude',
#        'location_description', 'longitude', 'n_guns_involved', 'notes',
#        'participant_age', 'participant_age_group', 'participant_gender',
#        'participant_name', 'participant_relationship', 'participant_status',
#        'participant_type', 'sources', 'state_house_district',
#        'state_senate_district'],
#       dtype='object')

# %%
#Keep the columns to analyze
df_new = df.drop(['incident_url', 'source_url','incident_url_fields_missing', 'congressional_district','sources', 'state_house_district',
       'state_senate_district','location_description','participant_name','notes'], axis=1)
df_new=df_new.set_index('incident_id')

# %%
#Try to split by gun type
#df_guns["gun_type"].str.strip()
gun_na=df_new.gun_type.dropna()
df_gun_na=pd.DataFrame(gun_na)
df_gun_na
# Out:
#                                        gun_type
# incident_id
# 478855                   0::Unknown||1::Unknown
# 478959                   0::Handgun||1::Handgun
# 479363             0::22 LR||1::223 Rem [AR-15]
# 491674                               0::Unknown
# 479413                               0::Unknown
# 479561                               0::Shotgun
# 479554                               0::Handgun
# 479573                               0::Handgun
# 479580                                   0::9mm
# 479603                               0::Handgun
# 480327                               0::45 Auto
# 480358                              0::12 gauge
# 481198                          0::7.62 [AK-47]
# 481213                               0::45 Auto
# 481229                               0::Handgun
# 481237                               0::Unknown
# 482771       0::9mm||1::9mm||2::40 SW||3::40 SW
# 482856                               0::Shotgun
# ...

# %%
df_gun_na[['Gun1','Gun2','Gun3','Gun4','Gun5','Gun6','Gun7','Gun8','Gun9','Gun10','Gun11','Gun12','Gun13','Gun14','Gun15','Gun16','Gun17','Gun18','Gun19','Gun20','Gun21','Gun22','Gun23','Gun24','Gun25','Gun26','Gun27','Gun28','Gun29','Gun30']]= df_gun_na['gun_type'].str.split('|',expand=True)
#df['Col2'] = df['Col1'].str.split('_').str[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-71e74eac5bfe> in <module>()
# ----> 1 df_gun_na[['Gun1','Gun2','Gun3','Gun4','Gun5','Gun6','Gun7','Gun8','Gun9','Gun10','Gun11','Gun12','Gun13','Gun14','Gun15','Gun16','Gun17','Gun18','Gun19','Gun20','Gun21','Gun22','Gun23','Gun24','Gun25','Gun26','Gun27','Gun28','Gun29','Gun30']]= df_gun_na['gun_type'].str.split('|',expand=True)
#       2 #df['Col2'] = df['Col1'].str.split('_').str[1]
#
# D:\Python\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3111             self._setitem_frame(key, value)
#    3112         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3113             self._setitem_array(key, value)
#    3114         else:
#    3115             # set column
#
# D:\Python\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
# ...

# %%
df_gun_na
# Out:
#                                        gun_type (Col2, Col3)
# incident_id
# 478855                   0::Unknown||1::Unknown
# 478959                   0::Handgun||1::Handgun
# 479363             0::22 LR||1::223 Rem [AR-15]
# 491674                               0::Unknown          NaN
# 479413                               0::Unknown          NaN
# 479561                               0::Shotgun          NaN
# 479554                               0::Handgun          NaN
# 479573                               0::Handgun          NaN
# 479580                                   0::9mm          NaN
# 479603                               0::Handgun          NaN
# 480327                               0::45 Auto          NaN
# 480358                              0::12 gauge          NaN
# 481198                          0::7.62 [AK-47]          NaN
# 481213                               0::45 Auto          NaN
# 481229                               0::Handgun          NaN
# ...
